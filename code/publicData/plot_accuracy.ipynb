# %%
#pulic data
import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']
gbdt = [92.5, 91.1, 92.6, 92.3, 92]
#dt = [89.4, 89.6, 88, 86.7, 91.4]
svm = [92, 92, 92, 93, 92]
rf = [94.2, 94.4, 95.3, 95, 94.9]
knn = [90, 90, 90, 90, 90]

plt.figure(figsize=(9, 5))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, marker='o', linestyle='-', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, 'o-.', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='best')
plt.ylim([85, 100])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Accuracy (%)', fontsize=15)
plt.title('Accuracy - Public dataset', fontsize=20)

plt.grid()
plt.show()
#plt.gca()
# Out:
# (85, 100)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Accuracy (%)')
# Text(0.5, 1.0, 'Accuracy - Public dataset')

# %%
# horizontal lines grid 

import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']
gbdt = [92.5, 91.1, 92.6, 92.3, 92]
#dt = [89.4, 89.6, 88, 86.7, 91.4]
svm = [92, 92, 92, 93, 92]
rf = [94.2, 94.4, 95.3, 95, 94.9]
knn = [90, 90, 90, 90, 90]

plt.figure(figsize=(8, 5))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, marker='o', linestyle='-', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, 'o-.', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='lower left')
plt.ylim([80, 100])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Accuracy (%)', fontsize=15)
plt.title('Accuracy - Public dataset', fontsize=18)

plt.axes().yaxis.grid(True)
#plt.grid()
plt.show()
#plt.gca()
# Out:
# (80, 100)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Accuracy (%)')
# Text(0.5, 1.0, 'Accuracy - Public dataset')
# C:\Users\dell\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']

gbdt = [92.2, 90.1, 90.9, 90.9, 90.4]
dt = [87.7, 87.3, 86.7, 82.8, 86.5]
svm = [86.9, 88.1, 87.3, 88.3, 88.1]
rf = [93.3, 93.3, 94, 93.5, 92.9]
knn = [86.6, 85.6, 85.1, 86.0, 85.7]

plt.figure(figsize=(8, 5))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, marker='o', linestyle='-', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, 'o-.', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='lower left')
plt.ylim([80, 100])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Accuracy (%)', fontsize=15)
plt.title('Accuracy - Public dataset', fontsize=18)
plt.grid(alpha=0.75)
plt.show()
# Out:
# (80, 100)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Accuracy (%)')
# Text(0.5, 1.0, 'Accuracy - Public dataset')

# %%
# Public data - Sensitivity

#horizontal lines grid 

import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']

gbdt = [92.2, 90.1, 90.9, 90.9, 90.4]
dt = [87.7, 87.3, 86.7, 82.8, 86.5]
svm = [86.9, 88.1, 87.3, 88.3, 88.1]
rf = [93.3, 93.3, 94, 93.5, 92.9]
knn = [86.6, 85.6, 85.1, 86.0, 85.7]

plt.figure(figsize=(8, 5))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, marker='o', linestyle='-', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, 'o-.', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='lower left')
plt.ylim([80, 100])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Sentivity (%)', fontsize=15)
plt.title('Sentivity - Public dataset', fontsize=18)

plt.axes().yaxis.grid(True)
#plt.grid(alpha=0.75)
plt.show()
#plt.gca()
# Out:
# (80, 100)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Sentivity (%)')
# Text(0.5, 1.0, 'Sentivity - Public dataset')
# C:\Users\dell\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# private data - Accuracy

# horizontal lines grid 

import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']
gbdt = [92.4, 99.5, 99, 99.5, 99.7]
#dt = [98.3, 88.2, 98.8, 99.5, 93.2]
svm = [99, 99, 99, 100, 100]
rf = [99.2, 99.8, 99.2, 99.5, 100]
knn = [99, 100, 99, 100, 100]

plt.figure(figsize=(10, 6))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, 'o-.', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, marker='o', linestyle='-', color='darkorange',lw = 3, label='KNN')


plt.legend(loc='lower right')
plt.ylim([92, 101])
plt.xlabel('Window size',fontsize=13 )
plt.ylabel('Accuracy (%)', fontsize=13)
plt.title('Accuracy - our dataset', fontsize=18)

plt.axes().yaxis.grid(True)
#plt.grid()
plt.show()
# Out:
# (92, 101)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Accuracy (%)')
# Text(0.5, 1.0, 'Accuracy - our dataset')
# C:\Users\dell\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
#private data - Sensitivity Macro 
#horizontal lines grid 

import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']

gbdt = [92.2, 99.2, 98.3, 99.1, 99.6]
svm = [97.4, 98.3, 98.1, 99.7, 99.2]
rf = [98.1, 99.8, 98.5, 99.1, 100]
knn = [97.2, 98.9, 98.4, 99.3, 99.2]

plt.figure(figsize=(10, 6))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, 'o-.', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, marker='o', linestyle='-', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='best')
plt.ylim([90, 102])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Sensitivity (%)', fontsize=15)
plt.title('Sensitivity', fontsize=20)

plt.axes().yaxis.grid(True)
#plt.grid(alpha=0.75)
plt.show()
# Out:
# (90, 102)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Sensitivity (%)')
# Text(0.5, 1.0, 'Sensitivity')
# C:\Users\dell\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
#private data - Sensitivity Micro 
#horizontal lines grid 

import matplotlib.pyplot as plt

window_size = ['5 s','8 s','10 s','12 s','15 s']

gbdt = [91.6, 99.5, 99.0, 99.5, 99.7]
svm = [98.8, 99.2, 99.2, 99.8, 99.7]
rf = [99.1, 99.8, 99.2, 99.5, 100]
knn = [98.8, 99.5, 99.4, 99.8, 99.7]

plt.figure(figsize=(10, 6))
plt.plot(window_size,gbdt, 'o--', color='red',  lw = 3,label='GBDT')

#plt.plot(window_size,dt, 'o-.', color='blueviolet',lw = 3, label='DT')

plt.plot(window_size,svm, marker='o', linestyle=':', color='blue',lw = 3, label='SVM')

plt.plot(window_size,rf, marker='o', linestyle='-', color='forestgreen',lw = 3, label='RF')

plt.plot(window_size,knn, marker='o', linestyle='-', color='darkorange',lw = 3, label='KNN')

plt.legend(loc='best')
plt.ylim([90, 102])
plt.xlabel('Window size',fontsize=15 )
plt.ylabel('Sensitivity (%)', fontsize=15)
plt.title('Sensitivity', fontsize=20)

plt.axes().yaxis.grid(True)
#plt.grid(alpha=0.75)
plt.show()
# Out:
# (90, 102)
# Text(0.5, 0, 'Window size')
# Text(0, 0.5, 'Sensitivity (%)')
# Text(0.5, 1.0, 'Sensitivity')
# C:\Users\dell\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
